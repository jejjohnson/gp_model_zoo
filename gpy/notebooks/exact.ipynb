# %% [markdown]
# # Exact GPs - Demo Notebook
#
# In this notebook, I will do a short demonstration for how we can use GPy with the simple wrapper.

# %%
import os, sys
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
sys.path.insert(0, parent_dir) 

import numpy as np
from exact import GPR, HeteroscedasticGPR
import GPy
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data

# %%
rng = np.random.RandomState(0)

# Generate sample data
noise = 0.5
n_train = 100
X = 15 * rng.rand(n_train, 1)

def f(x): return np.sin(x)

y = f(X)
y += 3 * (0.5 - rng.rand(X.shape[0], X.shape[1]))  # add noise
X_plot = np.linspace(0, 20, 10000)[:, None]

# %% [markdown]
# ### Plot Helper

# %%
def plot_results():
    # Plot results
    plt.figure(figsize=(10, 5))
    lw = 2
    plt.scatter(X, y, c='k', label='data')
    plt.plot(X_plot, np.sin(X_plot), color='navy', lw=lw, label='True')

    plt.plot(X_plot, y_gpr, color='darkorange', lw=lw,
             label='GPR' )
    plt.fill_between(X_plot[:, 0], 
                     (y_gpr - y_std).squeeze(), 
                     (y_gpr + y_std).squeeze(), color='darkorange',
                     alpha=0.2)
    plt.xlabel('data')
    plt.ylabel('target')
    plt.xlim(0, 20)
    plt.ylim(-4, 4)
    plt.title('GPR versus Kernel Ridge')
    plt.legend(loc="best",  scatterpoints=1, prop={'size': 8})
    plt.show()

# %% [markdown]
# ## Exact GP Model

# %%
gpr_clf = GPR(verbose=None, n_restarts=10)

gpr_clf.fit(X, y);

# %%
y_gpr, y_std = gpr_clf.predict(X_plot, return_std=True, noiseless=False)
plot_results()

# %%
y_gpr, y_std = gpr_clf.predict(X_plot, return_std=True, noiseless=True)
plot_results()
