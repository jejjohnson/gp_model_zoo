# %% [markdown]
# # Sparse GP w. MiniBatches

# %%
import os, sys
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
sys.path.insert(0, parent_dir) 

import numpy as np
from variational import SVGP, VGP
import GPy
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Data

# %%
rng = np.random.RandomState(0)

# Generate sample data
noise = 0.5
n_train = 1_000
n_test = 10_000
X = 15 * rng.rand(n_train, 1)

def f(x): return np.sin(x)

y = f(X)
y += 3 * (0.5 - rng.rand(X.shape[0], X.shape[1]))  # add noise
X_plot = np.linspace(0, 20, n_test)[:, None]

# %%
def plot_results():
    # Plot results
    plt.figure(figsize=(10, 5))
    lw = 2
    plt.scatter(X, y, c='k', label='data')
    plt.plot(X_plot, np.sin(X_plot), color='navy', lw=lw, label='True')

    plt.plot(X_plot, y_gpr, color='darkorange', lw=lw,
             label='GPR' )
    plt.fill_between(X_plot[:, 0], 
                     (y_gpr - y_std).squeeze(), 
                     (y_gpr + y_std).squeeze(), color='darkorange',
                     alpha=0.2)
    plt.xlabel('data')
    plt.ylabel('target')
    plt.xlim(0, 20)
    plt.ylim(-4, 4)
    plt.title('GPR versus Kernel Ridge')
    plt.legend(loc="best",  scatterpoints=1, prop={'size': 8})
    plt.show()

# %% [markdown]
# ## Model I - Variational GP

# %%
n_restarts = 0
max_iters  = 1_000
verbose    = 1

gpr_clf = VGP(
    verbose=verbose,
    n_restarts=n_restarts,
    max_iters=max_iters,
)

gpr_clf.fit(X, y);
# Out:
# Running Scaled Conjugate Gradients Code:
#   runtime   i      f              |g|
#     02s50  0009   3.673824e+04   2.978922e+09
#     07s45  0022   1.196472e+04   1.046830e+09
#     10s73  0032   5.094549e+03   1.216403e+08
#     14s20  0045   1.970769e+03   8.292823e+06
#     17s62  0056   1.383159e+03   3.689164e+05
#     21s11  0068   1.337718e+03   2.953739e+03
#     23s62  0075   1.337408e+03   9.404082e+02
#  01m00s78  0213   1.331328e+03   3.912560e+02
#  01m06s31  0235   1.330941e+03   2.453640e+02
#  02m02s91  0451   1.330663e+03   4.975571e+01
#  06m13s90  1261   1.330517e+03   2.709209e+00
#  06m39s63  1343   1.330515e+03   2.698463e+00
# Runtime:  06m39s63
# Optimization status: None
#
# KeyboardInterrupt caught, calling on_optimization_end() to round things up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-5479d6c53fc8> in <module>
#       9 )
#      10
# ---> 11 gpr_clf.fit(X, y);
#
# ~/Documents/code_projects/gp_model_zoo/gpy/variational.py in fit(self, X, y)
#     132                 self.optimizer,
#     133                 messages=self.verbose,
# --> 134                 max_iters=self.max_iters
#     135             )
#     136
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/GPy/core/gp.py in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     657         self.inference_method.on_optimization_start()
#     658         try:
# --> 659             ret = super(GP, self).optimize(optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     660         except KeyboardInterrupt:
#     661             print("KeyboardInterrupt caught, calling on_optimization_end() to round things up")
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/model.py in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     109
#     110         with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111             opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     112
#     113         self.optimizer_array = opt.x_opt
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/optimization/optimization.py in run(self, x_init, **kwargs)
#      49     def run(self, x_init, **kwargs):
#      50         start = dt.datetime.now()
# ---> 51         self.opt(x_init, **kwargs)
#      52         end = dt.datetime.now()
#      53         self.time = str(end - start)
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/optimization/optimization.py in opt(self, x_init, f_fp, f, fp)
#     236                          max_f_eval=self.max_f_eval,
#     237                          xtol=self.xtol, ftol=self.ftol,
# --> 238                          gtol=self.gtol)
#     239
#     240         self.x_opt = opt_result[0]
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/optimization/scg.py in SCG(f, gradf, x, optargs, maxiters, max_f_eval, xtol, ftol, gtol)
#     142                 # Update variables for new position
#     143                 gradold = gradnew
# --> 144                 gradnew = gradf(x, *optargs)
#     145                 function_eval += 1
#     146                 current_grad = np.dot(gradnew, gradnew)
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/model.py in _grads(self, x)
#     236         try:
#     237             # self._set_params_transformed(x)
# --> 238             self.optimizer_array = x
#     239             self.obj_grads = self._transform_gradients(self.objective_function_gradients())
#     240             self._fail_count = 0
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/parameterized.py in __setattr__(self, name, val)
#     337                 param = self.parameters[pnames.index(name)]
#     338                 param[:] = val; return
# --> 339         return object.__setattr__(self, name, val)
#     340
#     341     #===========================================================================
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/core/parameter_core.py in optimizer_array(self, p)
#     122
#     123         self._optimizer_copy_transformed = False
# --> 124         self.trigger_update()
#     125
#     126     def _trigger_params_changed(self, trigger_parent=True):
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/core/updateable.py in trigger_update(self, trigger_parent)
#      77             #print "Warning: updates are off, updating the model will do nothing"
#      78             return
# ---> 79         self._trigger_params_changed(trigger_parent)
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/core/parameter_core.py in _trigger_params_changed(self, trigger_parent)
#     132         """
#     133         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 134         self.notify_observers(None, None if trigger_parent else -np.inf)
#     135
#     136     def _size_transformed(self):
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/core/observable.py in notify_observers(self, which, min_priority)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/core/observable.py in <listcomp>(.0)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/core/parameter_core.py in _parameters_changed_notification(self, me, which)
#     506         """
#     507         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 508         self.parameters_changed()
#     509     def _pass_through_notify_observers(self, me, which=None):
#     510         self.notify_observers(which=which)
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/GPy/core/gp.py in parameters_changed(self)
#     265             this method yourself, there may be unexpected consequences.
#     266         """
# --> 267         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.mean_function, self.Y_metadata)
#     268         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
#     269         self.kern.update_gradients_full(self.grad_dict['dL_dK'], self.X)
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/GPy/inference/latent_function_inference/var_gauss.py in inference(self, kern, X, likelihood, Y, mean_function, Y_metadata, Z)
#      32         assert output_dim ==1, "Only one output supported"
#      33
# ---> 34         K = kern.K(X)
#      35         m = K.dot(self.alpha)
#      36         KB = K*self.beta[:, None]
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/GPy/kern/src/kernel_slice_operations.py in wrap(self, X, X2, *a, **kw)
#      84     def wrap(self, X, X2 = None, *a, **kw):
#      85         with _Slice_wrap(self, X, X2) as s:
# ---> 86             ret = f(self, s.X, s.X2, *a, **kw)
#      87         return ret
#      88     return wrap
#
# </Users/eman/anaconda3/envs/sci_py36/lib/python3.6/site-packages/decorator.py:decorator-gen-148> in K(self, X, X2)
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/caching.py in g(obj, *args, **kw)
#     281             else:
#     282                 cacher = cache[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs, cacher_enabled=cache.caching_enabled)
# --> 283             return cacher(*args, **kw)
#     284         g.__name__ = f.__name__
#     285         g.__doc__ = f.__doc__
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/paramz/caching.py in __call__(self, *args, **kw)
#     177             # If we need to compute, we compute the operation, but fail gracefully, if the operation has an error:
#     178             try:
# --> 179                 new_output = self.operation(*args, **kw)
#     180             except:
#     181                 self.reset()
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/GPy/kern/src/stationary.py in K(self, X, X2)
#     113         """
#     114         r = self._scaled_dist(X, X2)
# --> 115         return self.K_of_r(r)
#     116
#     117     @Cache_this(limit=3, ignore_args=())
#
# ~/anaconda3/envs/sci_py36/lib/python3.6/site-packages/GPy/kern/src/rbf.py in K_of_r(self, r)
#      49
#      50     def K_of_r(self, r):
# ---> 51         return self.variance * np.exp(-0.5 * r**2)
#      52
#      53     def dK_dr(self, r):
#
# KeyboardInterrupt:

# %%
gpr_clf.display_model()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-73ea20e279a6> in <module>
# ----> 1 gpr_clf.display_model()
#
# ~/Documents/code_projects/gp_model_zoo/gpy/variational.py in display_model(self)
#     141
#     142     def display_model(self):
# --> 143         return self.gp_model
#     144
#     145     def predict(self, X, return_std=False, noiseless=True):
#
# AttributeError: 'VGP' object has no attribute 'gp_model'

# %%
y_gpr, y_std = gpr_clf.predict(X_plot, return_std=True, noiseless=False)
plot_results()

# %%
y_gpr, y_std = gpr_clf.predict(X_plot, return_std=True, noiseless=True)
plot_results()

# %% [markdown]
# ## Model I - Sparse Variational GP

# %%
n_inducing = 100
n_restarts = 0
max_iters  = 1_000
verbose    = 1
batch_size = 50

gpr_clf = SVGP(
    verbose=verbose,
    n_restarts=n_restarts,
    n_inducing=n_inducing,
    max_iters=max_iters,
    batch_size=batch_size,
)

gpr_clf.fit(X, y);
# Out:
# Running Scaled Conjugate Gradients Code:
#   runtime   i      f              |g|
#     00s08  0001   7.067235e+04           nan
#     00s16  0002   7.067235e+04   5.182495e+09
#     01s18  0015   3.002188e+03   1.107113e+06
#     03s28  0043   2.560124e+03   2.985646e-02
#     04s07  0055   2.560124e+03   9.990576e-05
# Runtime:     04s07
# Optimization status: converged - relative reduction in objective

# %%
gpr_clf.display_model()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse gp<br>
# <b>Objective</b>: 2560.1241502842167<br>
# <b>Number of Parameters</b>: 103<br>
# <b>Number of Optimization Parameters</b>: 103<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sparse_gp.             </b></th><th><b>             value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  inducing inputs        </td><td class=tg-right>          (100, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>0.8151072242921877</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.77416897830968</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.7398064699613228</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
y_gpr, y_std = gpr_clf.predict(X_plot, return_std=True, noiseless=False)
plot_results()

# %%
y_gpr, y_std = gpr_clf.predict(X_plot, return_std=True, noiseless=True)
plot_results()
